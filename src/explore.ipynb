# %% [markdown]
# # Explore here

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/raw/diabetes_dataset.csv", delimiter=",")

# %%
df.describe()
# Out:
#         Unnamed: 0           Age           BMI  Waist_Circumference  \
# count  10000.00000  10000.000000  10000.000000          10000.00000
# mean    4999.50000     44.620400     29.418150             94.79707
# std     2886.89568     14.343489      6.170866             14.38329
# min        0.00000     20.000000     18.500000             70.00000
# 25%     2499.75000     32.000000     24.100000             82.20000
# 50%     4999.50000     45.000000     29.500000             94.90000
# 75%     7499.25000     57.000000     34.700000            107.00000
# max     9999.00000     69.000000     40.000000            120.00000
#
#        Fasting_Blood_Glucose         HbA1c  Blood_Pressure_Systolic  \
# count           10000.000000  10000.000000             10000.000000
# mean              134.776210      9.507510               134.163700
# std                37.633544      3.176421                26.110317
# min                70.000000      4.000000                90.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Unnamed: 0                     10000 non-null  int64
#  1   Age                            10000 non-null  int64
#  2   Sex                            10000 non-null  object
#  3   Ethnicity                      10000 non-null  object
#  4   BMI                            10000 non-null  float64
#  5   Waist_Circumference            10000 non-null  float64
#  6   Fasting_Blood_Glucose          10000 non-null  float64
#  7   HbA1c                          10000 non-null  float64
#  8   Blood_Pressure_Systolic        10000 non-null  int64
#  9   Blood_Pressure_Diastolic       10000 non-null  int64
#  10  Cholesterol_Total              10000 non-null  float64
#  11  Cholesterol_HDL                10000 non-null  float64
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  Age     Sex Ethnicity   BMI  Waist_Circumference  \
# 0           0   58  Female     White  35.8                 83.4
# 1           1   48    Male     Asian  24.1                 71.4
# 2           2   34  Female     Black  25.0                113.8
# 3           3   62    Male     Asian  32.7                100.4
# 4           4   27  Female     Asian  33.5                110.8
#
#    Fasting_Blood_Glucose  HbA1c  Blood_Pressure_Systolic  \
# 0                  123.9   10.9                      152
# 1                  183.7   12.8                      103
# 2                  142.0   14.5                      179
# 3                  167.4    8.8                      176
# 4                  146.4    7.1                      122
#
#    Blood_Pressure_Diastolic  ...  Cholesterol_HDL  Cholesterol_LDL   GGT  \
# 0                       114  ...             50.2             99.2  37.5
# 1                        91  ...             62.0            146.4  88.5
# ...

# %%
df.tail()
# Out:
#       Unnamed: 0  Age     Sex Ethnicity   BMI  Waist_Circumference  \
# 9995        9995   45  Female     Asian  39.4                114.0
# 9996        9996   41  Female     Asian  21.0                 71.3
# 9997        9997   50  Female     Asian  29.0                106.3
# 9998        9998   62  Female     White  27.3                119.9
# 9999        9999   29    Male     Black  20.6                102.0
#
#       Fasting_Blood_Glucose  HbA1c  Blood_Pressure_Systolic  \
# 9995                   76.2   13.4                      109
# 9996                   77.1   12.9                      154
# 9997                   97.5    4.9                      122
# 9998                   89.0   11.5                       99
# 9999                   70.8   14.5                      156
#
#       Blood_Pressure_Diastolic  ...  Cholesterol_HDL  Cholesterol_LDL   GGT  \
# 9995                        82  ...             60.3             88.7  19.1
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(style="whitegrid")


features = df.select_dtypes(include=['float64', 'int64']).columns.tolist()

fig, ax = plt.subplots(len(features), 2, figsize=(20, 32), 
                       gridspec_kw={'height_ratios': [6, 1] * (len(features) // 2)})

for i, feature in enumerate(features):
    row = (i // 2) * 2 
    col = i % 2
    sns.histplot(ax=ax[row, col], data=df, x=feature)
    sns.boxplot(ax=ax[row + 1, col], data=df, x=feature).set(xlabel=None)


plt.tight_layout()
plt.show()

# %% [markdown]
# # **Histogram Analysis of Health-related Variables**
#
# Understanding the distribution of health indicators is fundamental in medical research. The following histograms provide insight into the spread of various metrics.
#
# ## **Key Observations**
# - **Age Distribution**: Most individuals fall within the 40–60 age range, with fewer younger and older participants.
# - **BMI & Waist Circumference**: A normal distribution suggests most individuals have BMI values between 20 and 40 and waist circumferences between 70 and 120 cm.
# - **Fasting Blood Glucose & HbA1c Levels**: These show a right-skewed distribution, indicating that a subset of individuals has elevated glucose levels, which is crucial in diabetes assessment.
# - **Blood Pressure (Systolic & Diastolic)**: The systolic and diastolic blood pressure distributions show expected clinical ranges, with outliers indicating potential hypertension cases.
# - **Cholesterol Levels (Total, HDL, LDL)**: These distributions help in assessing cardiovascular risk, with most values falling within standard medical ranges.
# - **Dietary Intake & Family History of Diabetes**: A binary distribution for family history reveals that a portion of the population has a genetic predisposition, which can be a significant risk factor.
#
# ## **Interpretation**
# These histograms provide an essential view into the distribution of health indicators, aiding in epidemiological studies and risk assessment. Identifying trends within these metrics supports informed medical decision-making.
#
# This markdown will display elegantly in Jupyter Notebook, making your analysis structured and visually appealing. Let me know if you’d like any modifications! 🚀

# %%
def identify_outliers(df):
    outlier_info = {}

    for col in df.select_dtypes(include='number').columns:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1 

        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

        if not outliers.empty:
            outlier_info[col] = {
                'outliers_count': outliers.shape[0],
                'lower_bound': lower_bound,
                'upper_bound': upper_bound,
                'outlier_values': outliers[col].tolist()
            }

    for col, info in outlier_info.items():
        print(f"Column: {col}")
        print(f"  Number of outliers: {info['outliers_count']}")
        print(f"  Low Limit: {info['lower_bound']}")
        print(f"  High Limit: {info['upper_bound']}")
        print(f"  Outliers: {info['outlier_values'][:5]}...\n")
    return outlier_info

# %%
outlier_info = identify_outliers(df)

# %%
def remove_outliers(df, outlier_info):
    
    for col, info in outlier_info.items():
        if col == 'smoke' or col.startswith('region_'):
            continue
        lower_limit = info['lower_bound']
        upper_limit = info['upper_bound']
        
        if lower_limit < 0:
            df = df[df[col] >= lower_limit]
        if upper_limit > 0:
            df = df[df[col] <= upper_limit]

        
    return df

# %%
df['Diabetes'] = df.apply(lambda row: 1 if row['HbA1c'] > 6.5 or row['Fasting_Blood_Glucose'] > 126 else 0, axis=1)

print(df['Diabetes'].value_counts())
# Out:
# Diabetes
# 1    9016
# 0     984
# Name: count, dtype: int64

# %%
import numpy as np

# Correlation heatmap
plt.figure(figsize=(12, 10))

corr_matrix = df.select_dtypes(include="number").corr()

mask = np.triu(np.ones_like(corr_matrix, dtype=bool))

sns.heatmap(
    corr_matrix, 
    mask=mask,
    annot=True, 
    fmt=".2f",
    cmap="coolwarm",
    center=0,
    linewidths=0.5,
    square=True,
    cbar=False,
    cbar_kws={"shrink": 0.75},
    annot_kws={"size": 10}
)

plt.title("Correlation Matrix", fontsize=16, fontweight="bold", pad=20)
plt.xticks(fontsize=12, rotation=45, ha="right")
plt.yticks(fontsize=12)

plt.show()

# %% [markdown]
# # **Correlation Analysis of Diabetes-related Variables**
#
# Understanding the relationships between health indicators is crucial in medical research. The following correlation matrix illustrates the connections between various variables related to diabetes.
#
# ## **Key Observations**
# - **HbA1c vs. Diabetes (0.44)**: This moderate correlation suggests that higher HbA1c levels are associated with diabetes. Since HbA1c is a measure of long-term blood glucose levels, this result is expected.
# - **Fasting Glucose vs. Diabetes (0.33)**: A positive correlation indicates that elevated fasting glucose levels are linked to diabetes, reinforcing the importance of blood sugar monitoring.
# - **Other Variables**: Some correlations appear weaker, suggesting minimal direct relationships with diabetes in this dataset.
#
# ## **Interpretation**
# Strong correlations can guide clinical decisions and further research. Medical practitioners often rely on such analyses to refine diagnostic criteria and risk assessments.
#
# This matrix serves as a powerful tool for understanding the interplay between various health metrics, providing valuable insights for preventive healthcare and disease management.

# %%
df = df[["Diabetes", "Fasting_Blood_Glucose", "HbA1c"]]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Diabetes               10000 non-null  int64
#  1   Fasting_Blood_Glucose  10000 non-null  float64
#  2   HbA1c                  10000 non-null  float64
# dtypes: float64(2), int64(1)
# memory usage: 234.5 KB

# %%
print(df["Diabetes"].value_counts())
# Out:
# Diabetes
# 1    9016
# 0     984
# Name: count, dtype: int64

# %%
df.to_csv("../data/processed/diabetes_dataset_cleaned.csv", index=False)

# %%
from imblearn.over_sampling import SMOTE
import pandas as pd

smote = SMOTE(random_state=42)

X_resampled, y_resampled = smote.fit_resample(df.drop(columns=["Diabetes"]), df["Diabetes"])

df = pd.DataFrame(X_resampled, columns=["Fasting_Blood_Glucose", "HbA1c"])
df["Diabetes"] = y_resampled


print(df["Diabetes"].value_counts())
# Out:
# Diabetes
# 1    9016
# 0    9016
# Name: count, dtype: int64

# %%
dataframe_without_outliers = remove_outliers(df, outlier_info)

dataframe_without_outliers.describe().round(2)
# Out:
#        Fasting_Blood_Glucose     HbA1c  Diabetes
# count               18032.00  18032.00   18032.0
# mean                  118.17      7.62       0.5
# std                    35.31      3.20       0.5
# min                    70.00      4.00       0.0
# 25%                    89.33      5.10       0.0
# 50%                   110.52      6.18       0.5
# 75%                   141.10     10.10       1.0
# max                   200.00     15.00       1.0

# %%
from sklearn.model_selection import train_test_split


def train_split(target, dataframe, test_size=0.2, random_state=42):
    return train_test_split(dataframe.drop(columns=target), dataframe[target], test_size=test_size, random_state=random_state)

# %%
TARGET = 'Diabetes'
X_train_with_outliers, X_test_with_outliers, y_train, y_test = train_split(TARGET, df.copy())
X_train_without_outliers, X_test_without_outliers, y_train_without_outliers, y_test_without_outliers  = train_split(TARGET, dataframe_without_outliers)

#Default
X_train_with_outliers.to_csv('../data/processed/X_train_with_outliers_ts_02_rs_42.csv', index=False)
X_test_with_outliers.to_csv('../data/processed/X_test_with_outliers_ts_02_rs_42.csv', index=False)

y_train.to_csv('../data/processed/y_train.csv', index=False)
y_test.to_csv('../data/processed/y_test.csv', index=False)

#Without outliers
X_train_without_outliers.to_csv('../data/processed/X_train_without_outliers_ts_02_rs_42.csv', index=False)
X_test_without_outliers.to_csv('../data/processed/X_test_without_outliers_ts_02_rs_42.csv', index=False)

y_train_without_outliers.to_csv('../data/processed/y_train_without_outliers.csv', index=False)
y_test_without_outliers.to_csv('../data/processed/y_test_without_outliers.csv', index=False)

# %%
dfs_train = {
    'X_train_with_outliers_selected': X_train_with_outliers
}

dfs_train_without_outliers = {
    'X_train_without_outliers_selected': X_train_without_outliers
}

dfs_test = {
    'X_test_with_outliers_selected': X_test_with_outliers
}

dfs_test_without_outliers = {
    'X_test_without_outliers_selected': X_test_without_outliers
}

for name, df in dfs_train.items():
    df.to_csv(f"../data/processed/{name}.csv", index=False)

for name, df in dfs_test.items(): 
    df.to_csv(f'../data/processed/{name}.csv', index=False)

for name, df in dfs_train_without_outliers.items():
    df.to_csv(f"../data/processed/{name}.csv", index=False)

for name, df in dfs_test_without_outliers.items(): 
    df.to_csv(f'../data/processed/{name}.csv', index=False)

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

train = list(dfs_train.values())
test = list(dfs_test.values())
train_without_outliers = list(dfs_train_without_outliers.values())
test_without_outliers = list(dfs_test_without_outliers.values())

results = []

# Default
for index, train_df in enumerate(train):
    model = RandomForestClassifier(random_state=42)
    model.fit(train_df, y_train)
    y_pred = model.predict(test[index])
    
    accuracy = accuracy_score(y_test, y_pred)
    precision = precision_score(y_test, y_pred)
    recall = recall_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)

    results.append({
        'index': index,
        'df_train': list(dfs_train.keys())[index],
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'y_pred': y_pred,
        'model': model
    })

# Without outliers
for index, train_df in enumerate(train_without_outliers):
    model = RandomForestClassifier(random_state=42)
    model.fit(train_df, y_train_without_outliers)
    y_pred = model.predict(test_without_outliers[index])
    
    accuracy = accuracy_score(y_test_without_outliers, y_pred)
    precision = precision_score(y_test_without_outliers, y_pred)
    recall = recall_score(y_test_without_outliers, y_pred)
    f1 = f1_score(y_test_without_outliers, y_pred)

    results.append({
        'index': index,
        'df_train': list(dfs_train_without_outliers.keys())[index],
        'accuracy': accuracy,
        'precision': precision,
        'recall': recall,
        'f1_score': f1,
        'y_pred': y_pred,
        'model': model
    })

# Ordenar resultados por precisión
results = sorted(results, key=lambda x: x['accuracy'], reverse=True)
best_result = results[0]

print(f"Index: {best_result['index']}")
print(f"\ndf_train: {best_result['df_train']}")
print(f"Accuracy: {best_result['accuracy']}")
print(f"Precision: {best_result['precision']}")
print(f"Recall: {best_result['recall']}")
print(f"F1 Score: {best_result['f1_score']}")
print(f"Y_pred: {best_result['y_pred'][:5]}...")
# Out:
# Index: 0
#
# df_train: X_train_with_outliers_selected
# Accuracy: 1.0
# Precision: 1.0
# Recall: 1.0
# F1 Score: 1.0
# Y_pred: [0 1 0 0 0]...

# %%
from joblib import dump

dump(best_result["model"], "../models/best_random_forest_classifier_without_hyperparams.joblib")
print("Modelo guardado correctamente.")
# Out:
# Modelo guardado correctamente.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

param_grid = {
    'n_estimators': [50, 100, 200],     
    'max_depth': [None, 10, 20, 30],    
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4],     
}

grid_search = GridSearchCV(estimator=RandomForestClassifier(random_state=42),
                           param_grid=param_grid,
                           scoring='accuracy',
                           cv=3,          
                           verbose=2,     
                           n_jobs=-1)     

best_results = []

# Default
for index, train_df in enumerate(train):
    grid_search.fit(train_df, y_train)
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(test[index])

    accuracy = accuracy_score(y_test, y_pred)
    

    best_results.append({
        'index': index,
        'df_train': list(dfs_train.keys())[index],
        'best_params': grid_search.best_params_,
        'accuracy': accuracy,
        'y_pred': y_pred,
        'model': best_model
    })

for index, train_df in enumerate(train_without_outliers):
    grid_search.fit(train_df, y_train_without_outliers)
    best_model = grid_search.best_estimator_
    y_pred = best_model.predict(test_without_outliers[index])

    accuracy = accuracy_score(y_test_without_outliers, y_pred)  

    best_results.append({
        'index': index,
        'df_train': list(dfs_train_without_outliers.keys())[index],
        'best_params': grid_search.best_params_,
        'accuracy': accuracy,
        'y_pred': y_pred,
        'model': best_model
    })

best_results = sorted(best_results, key=lambda x: x['accuracy'], reverse=True)
best_model_result = best_results[0]

print(f"Index: {best_model_result['index']}")
print(f"df_train: {best_model_result['df_train']}")
print(f"Best Parameters: {best_model_result['best_params']}")
print(f"Accuracy: {best_model_result['accuracy']}")
print(f"Y_pred: {best_model_result['y_pred'][:5]}...")
# Out:
# Fitting 3 folds for each of 108 candidates, totalling 324 fits
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.5s
# [CV] END max_depth=None, min_samples_leaf=1, min_samples_split=5, n_estimators=50; total time=   0.3s
# ...

# %%
from joblib import dump
dump(best_model_result['model'], '../models/best_random_forest_model.joblib')
# Out:
# ['../models/best_random_forest_model.joblib']

# %%
import joblib
import numpy as np


model = joblib.load("../models/best_random_forest_model.joblib")

example_inputs = np.array([
    [85, 5.0],  # Bajo riesgo de diabetes
    [120, 7.5],  # Caso intermedio
    [160, 11.0], # Posible caso de diabetes
    [99, 6.0],   # Límite bajo
    [170, 12.5]  # Alta probabilidad de diabetes
])

predictions = model.predict(example_inputs)

mapped_results = ["Positivo" if pred == 1.0 else "Negativo" for pred in predictions]

for i, (input_values, result) in enumerate(zip(example_inputs, mapped_results)):
    print(f"Ejemplo {i + 1}: Glucosa={input_values[0]}, HbA1c={input_values[1]} → Predicción: {result}")
# Out:
# Ejemplo 1: Glucosa=85.0, HbA1c=5.0 → Predicción: Negativo
# Ejemplo 2: Glucosa=120.0, HbA1c=7.5 → Predicción: Positivo
# Ejemplo 3: Glucosa=160.0, HbA1c=11.0 → Predicción: Positivo
# Ejemplo 4: Glucosa=99.0, HbA1c=6.0 → Predicción: Negativo
# Ejemplo 5: Glucosa=170.0, HbA1c=12.5 → Predicción: Positivo
# /workspaces/ml_web_app_using_flask/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
